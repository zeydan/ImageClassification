# %%
import torch
import torch.nn as nn
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
mean = np.array([0.5, 0.5, 0.5])
std = np.array([0.25, 0.25, 0.25])

# Initialize transforms
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.RandomResizedCrop(224),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean, std)
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean, std)
])

# Import the train and test data from a folder
train_data = torchvision.datasets.ImageFolder('data/train/', transform=train_transform)
test_data = torchvision.datasets.ImageFolder('data/test/', transform=test_transform)

# Separate images into batches with dataloader
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=False)

# Get each dataloader size
train_dataset_size = len(train_dataloader)
test_dataset_size = len(test_dataloader)

# %%
# To visualize the training operation
train_accuracies = []
train_losses = []
test_accuracies = []
test_losses = []

def train_model(model, loss_fn, optimizer, epochs):
    # In order to get the best model from the training operation
    best_accuracy = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())

    # Training begins here
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0.0
        train_accuracy = 0.0
        
        # This inner loop is for training by batches
        for i, (images, labels) in enumerate(train_dataloader, 1):
            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward, Backward and Optimize
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()

            # Get loss and accuracy results
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            corrects = torch.sum(preds == labels)
            accuracy = corrects.item() / len(labels)
            train_accuracy += accuracy
            print(f'Train Mode | Epoch: {epoch} | Step: {i} | Loss: {loss.item()} | Accuracy: {accuracy}')

        # Append train_loss and train_accuracy results to the lists by batches to visualize
        train_loss = train_loss / train_dataset_size
        train_losses.append(train_loss)
        train_accuracy = train_accuracy / train_dataset_size
        train_accuracies.append(train_accuracy)
        
        model.eval()
        test_loss = 0.0
        test_accuracy = 0.0

        # Test section begins here
        # Note: I put the test section in the training loop because I wanted to get the best model according to the test accuracy
        with torch.inference_mode():
            for i, (images, labels) in enumerate(test_dataloader, 1):
                outputs = model(images)
                loss = loss_fn(outputs, labels)

                _, preds = torch.max(outputs, 1)
                corrects = torch.sum(preds == labels)
                accuracy = corrects.item() / len(labels)
                test_accuracy += accuracy
                test_loss += loss.item()
                print(f'Test Mode | Epoch: {epoch} | Step: {i} | Loss: {loss.item()} | Accuracy: {accuracy}')
        
        # Append test_loss and test_accuracy results to the lists by batches to visualize
        test_loss = test_loss / test_dataset_size
        test_losses.append(test_loss)
        test_accuracy = test_accuracy / test_dataset_size
        test_accuracies.append(test_accuracy)

        # Get the best model according to the test accuracy
        if test_accuracy > best_accuracy:
            best_accuracy = test_accuracy
            best_model_wts = copy.deepcopy(model.state_dict())
            print(f'New best accuracy: {best_accuracy}')

    # Set the best model as default model
    model.load_state_dict(best_model_wts)
    print(f'The final best accuracy: {best_accuracy}')
    return model

# %%
# Get a pretrained model
model = torchvision.models.resnet18(weights=torchvision.models.ResNet18_Weights.DEFAULT)

# Comment here for Fine Tuning (Train all layers)
# Uncomment here for Feature Extraction (Train the last layer)
for param in model.parameters():
    param.requires_grad = False

# Edit the last layer according to the new dataset
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Initialize loss function (CrossEntropyLoss for multiclass classification)
loss_fn = nn.CrossEntropyLoss()

# Initialize optimizer (SGD - Stochastic Gradient Descent, lr - learning rate, momentum - momentum factor)
optimizer = torch.optim.SGD(model.fc.parameters(), lr=0.001, momentum=0.9)

# Run the training function
model = train_model(model, loss_fn, optimizer, epochs=20)
# Out:
# Train Mode | Epoch: 1 | Step: 1 | Loss: 0.7864260077476501 | Accuracy: 0.625
# Train Mode | Epoch: 1 | Step: 2 | Loss: 0.8932551741600037 | Accuracy: 0.4375
# Train Mode | Epoch: 1 | Step: 3 | Loss: 0.7246361374855042 | Accuracy: 0.59375
# Train Mode | Epoch: 1 | Step: 4 | Loss: 0.7426233291625977 | Accuracy: 0.5
# Train Mode | Epoch: 1 | Step: 5 | Loss: 0.7667946219444275 | Accuracy: 0.53125
# Train Mode | Epoch: 1 | Step: 6 | Loss: 0.7173501253128052 | Accuracy: 0.53125
# Train Mode | Epoch: 1 | Step: 7 | Loss: 0.6630057096481323 | Accuracy: 0.5625
# Train Mode | Epoch: 1 | Step: 8 | Loss: 0.546760082244873 | Accuracy: 0.65
# Test Mode | Epoch: 1 | Step: 1 | Loss: 1.1137797832489014 | Accuracy: 0.0625
# Test Mode | Epoch: 1 | Step: 2 | Loss: 1.3104194402694702 | Accuracy: 0.0625
# Test Mode | Epoch: 1 | Step: 3 | Loss: 0.43782535195350647 | Accuracy: 0.8125
# Test Mode | Epoch: 1 | Step: 4 | Loss: 0.23224762082099915 | Accuracy: 1.0
# Test Mode | Epoch: 1 | Step: 5 | Loss: 0.24095506966114044 | Accuracy: 0.96
# New best accuracy: 0.5795
# Train Mode | Epoch: 2 | Step: 1 | Loss: 0.8609005212783813 | Accuracy: 0.4375
# Train Mode | Epoch: 2 | Step: 2 | Loss: 0.6403914093971252 | Accuracy: 0.625
# Train Mode | Epoch: 2 | Step: 3 | Loss: 0.5842231512069702 | Accuracy: 0.71875
# Train Mode | Epoch: 2 | Step: 4 | Loss: 0.5504915118217468 | Accuracy: 0.625
# Train Mode | Epoch: 2 | Step: 5 | Loss: 0.5031000971794128 | Accuracy: 0.78125
# Train Mode | Epoch: 2 | Step: 6 | Loss: 0.48670846223831177 | Accuracy: 0.875
# Train Mode | Epoch: 2 | Step: 7 | Loss: 0.4816255569458008 | Accuracy: 0.84375
# Train Mode | Epoch: 2 | Step: 8 | Loss: 0.42924079298973083 | Accuracy: 0.85
# Test Mode | Epoch: 2 | Step: 1 | Loss: 0.2604559063911438 | Accuracy: 0.96875
# Test Mode | Epoch: 2 | Step: 2 | Loss: 0.2994627058506012 | Accuracy: 1.0
# Test Mode | Epoch: 2 | Step: 3 | Loss: 0.5096912384033203 | Accuracy: 0.84375
# Test Mode | Epoch: 2 | Step: 4 | Loss: 0.5687210559844971 | Accuracy: 0.6875
# Test Mode | Epoch: 2 | Step: 5 | Loss: 0.6790270209312439 | Accuracy: 0.6
# New best accuracy: 0.82
# Train Mode | Epoch: 3 | Step: 1 | Loss: 0.49080437421798706 | Accuracy: 0.6875
# Train Mode | Epoch: 3 | Step: 2 | Loss: 0.37805378437042236 | Accuracy: 0.90625
# Train Mode | Epoch: 19 | Step: 6 | Loss: 0.2122100293636322 | Accuracy: 0.875
# Train Mode | Epoch: 19 | Step: 7 | Loss: 0.1076926589012146 | Accuracy: 0.96875
# Train Mode | Epoch: 19 | Step: 8 | Loss: 0.10012269020080566 | Accuracy: 0.95
# Test Mode | Epoch: 19 | Step: 1 | Loss: 0.1978718489408493 | Accuracy: 0.96875
# Test Mode | Epoch: 19 | Step: 2 | Loss: 0.11411234736442566 | Accuracy: 0.96875
# Test Mode | Epoch: 19 | Step: 3 | Loss: 0.10480311512947083 | Accuracy: 0.9375
# Test Mode | Epoch: 19 | Step: 4 | Loss: 0.07523932307958603 | Accuracy: 1.0
# Test Mode | Epoch: 19 | Step: 5 | Loss: 0.3340853750705719 | Accuracy: 0.84
# Train Mode | Epoch: 20 | Step: 1 | Loss: 0.19684632122516632 | Accuracy: 0.90625
# Train Mode | Epoch: 20 | Step: 2 | Loss: 0.17973941564559937 | Accuracy: 0.875
# Train Mode | Epoch: 20 | Step: 3 | Loss: 0.24793022871017456 | Accuracy: 0.875
# Train Mode | Epoch: 20 | Step: 4 | Loss: 0.10108909010887146 | Accuracy: 1.0
# Train Mode | Epoch: 20 | Step: 5 | Loss: 0.16135820746421814 | Accuracy: 0.96875
# Train Mode | Epoch: 20 | Step: 6 | Loss: 0.16883781552314758 | Accuracy: 0.90625
# Train Mode | Epoch: 20 | Step: 7 | Loss: 0.1697188764810562 | Accuracy: 0.90625
# Train Mode | Epoch: 20 | Step: 8 | Loss: 0.2000914067029953 | Accuracy: 0.9
# Test Mode | Epoch: 20 | Step: 1 | Loss: 0.217304527759552 | Accuracy: 0.96875
# Test Mode | Epoch: 20 | Step: 2 | Loss: 0.13664261996746063 | Accuracy: 0.96875
# Test Mode | Epoch: 20 | Step: 3 | Loss: 0.08623309433460236 | Accuracy: 0.9375
# Test Mode | Epoch: 20 | Step: 4 | Loss: 0.05970030277967453 | Accuracy: 1.0
# Test Mode | Epoch: 20 | Step: 5 | Loss: 0.2923796772956848 | Accuracy: 0.88
# The final best accuracy: 0.951

# %%
# Visualize the losses by epochs
plt.scatter(range(1,len(train_losses)+1), train_losses, c='r')
plt.scatter(range(1, len(test_losses)+1), test_losses, c='b')
plt.show()

# %%
# Visualize the accuracy by epochs
plt.scatter(range(1,len(train_accuracies)+1), train_accuracies, c='r')
plt.scatter(range(1,len(test_accuracies)+1), test_accuracies, c='b')
plt.show()

# %%
# Test the model with a single image
from PIL import Image
pil_image = Image.open('ant.jpg')

# Apply transform to the image
image = test_transform(pil_image)

# Make a prediction (unsqueeze the image to set it as a batch, squeeze the result to reduce the dimension, softmax the result to convert the prediction to the percent)
prediction = model(image.unsqueeze(dim=0)).squeeze(0).softmax(0)

# Get the id of the maximum score in the prediction
class_id = prediction.argmax().item()

# Get the score of the result
score = prediction[class_id].item()

# Get the category name
category_name = test_data.classes[class_id]

print(f'Category name of the image: {category_name}, Score: {100 * score:.1f}%')
# Out:
# Category name of the image: ants, Score: 94.4%
